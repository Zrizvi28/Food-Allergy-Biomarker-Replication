# %% [markdown]
# Loading Data
#
# (So, this was abandoned by me once I realized I don't have enough time to do everything I wanted to...but here's the first step in case anybody wants to test it out)

# %%
import pandas as pd

snp_meta = pd.read_csv('data/GSE189148_sample_metadata_snp_annotated.csv')
print(snp_meta.shape)
print(snp_meta['stimulation_status'].value_counts())
# Out:
# (88, 12)
# stimulation_status
# S    45
# U    43
# Name: count, dtype: int64
